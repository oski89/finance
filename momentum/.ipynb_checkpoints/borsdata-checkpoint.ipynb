# %%
# Inputs

INPUT_FILE = 'datas/Borsdata_2021-01-04.xlsx'

MONEY_TO_USE = 130000
NO_COMPS_TO_BUY = 25

# %%
# Import pandas and ignore warnings

import pandas as pd
pd.set_option('mode.chained_assignment', None)

# %%
# Read Excel file and sort by company name

df = pd.read_excel(INPUT_FILE,header=[0,1],index_col=0)
df.sort_index(inplace=True)

# %%
# Apply filter: enterprise value > 1000 MSEK with positive momentums and trends

ev1000 = df['Börsvärde']['Senaste'] > 1000
utv3 = df['Kursutveck.']['Utveck.  3m'] > 0
utv6 = df['Kursutveck.']['Utveck.  6m'] > 0
utv12 = df['Kursutveck.']['Utveck.  1 år'] > 0
utv6vs3 = df['Kursutveck.']['Utveck.  6m'] > df['Kursutveck.']['Utveck.  3m']
utv12vs6 = df['Kursutveck.']['Utveck.  1 år'] > df['Kursutveck.']['Utveck.  6m']
ma50 = df['Kurs / MA']['MA 50d'] > 0
ma200 = df['Kurs / MA']['MA 200d'] > 0
ma200vs50 = df['Kurs / MA']['MA 200d'] > df['Kurs / MA']['MA 50d']

df_filt = df[ev1000 & utv3 & utv6 & utv12 & utv6vs3 & utv12vs6 & ma50 & ma200 & ma200vs50]

# %%
# Add momentum ranks and sort by total rank

header = pd.MultiIndex.from_product([['Momentum rank'],
                                     ['Rank 3m','Rank 6m','Rank 1 år','Tot']])
header2 = pd.MultiIndex.from_product([['Kursutveck.'],
                                     ['Utveck.  3m','Utveck.  6m','Utveck.  1 år']])

for i in range(3):
    df_filt[header[i]] = df_filt[header2[i]].rank(ascending=False,method='first').astype(int)
df_filt[header[3]] = (df_filt[header[0]] + df_filt[header[1]] + df_filt[header[2]]).rank(ascending=True,method='first').astype(int)
df_filt.sort_values(by=[header[3]],inplace=True)

# %%
# Display amount of stocks to buy for each company

money_per_stock = MONEY_TO_USE / NO_COMPS_TO_BUY
df_filt['Antal aktier'] = round(money_per_stock / df_filt['Aktiekurs']['Senaste']).astype(int)
df_filt.head(NO_COMPS_TO_BUY)
# Out:
# Bolagsnamn                    Info     Börsvärde    Aktiekurs Kursutveck.  \
#                              Lista       Senaste      Senaste Utveck.  3m
# Azelio                 First North   5422.542969    59.099998    1.217636
# Bayn Group             First North   1398.421997    14.880000    0.932468
# Bambuser               First North   2067.155029    17.400000    0.786448
# Enad Global 7          First North   4216.054199   120.500000    0.544872
# Zinzino                First North   2417.436035    74.199997    0.809756
# Swedencare             First North   5242.240234   320.000000    0.531100
# Cantargia                  Mid Cap   5843.200195    66.400002    0.366255
# Biovica                First North   1464.541016    51.799999    0.366755
# Sinch                    Large Cap  79314.023438  1376.000000    0.680098
# BHG Group                Large Cap  19648.339844   183.000000    0.443218
# Boozt                      Mid Cap  10521.400391   183.000000    0.452381
# Volati                     Mid Cap   8258.223633   104.000000    0.473088
# Ascelia Pharma           Small Cap   1376.900024    56.200001    0.510753
# Sdiptech               First North   7222.355957   228.000000    0.425000
# OrganoClick            First North   1031.654053    11.200000    0.728395
# Eolus Vind                 Mid Cap   6356.267090   255.199997    0.500294
# Intervacc              First North   2686.645996    53.599998    0.307317
# Kambi                  First North  11855.919922   395.000000    0.360193
# G5 Entertainment           Mid Cap   3689.425049   425.000000    0.148649
# VNV Global                 Mid Cap   9452.646484   119.000000    0.636864
# Cellink                    Mid Cap  10665.849609   252.500000    0.208134
# Mips                       Mid Cap  13822.820312   533.000000    0.350051
# GARO                       Mid Cap   6360.000000   636.000000    0.297959
# Invisio                    Mid Cap  11024.500000   250.000000    0.461988
# Sivers Semiconductors  First North   4364.714844    33.500000    0.053459
#
# Bolagsnamn                                      Kurs / MA            \
#                       Utveck.  6m Utveck.  1 år    MA 50d   MA 200d
# Azelio                   2.940000      3.828431  0.478609  1.637998
# Bayn Group               2.277533      9.156996  0.601584  1.461133
# Bambuser                 1.979452      9.740740  0.277027  0.900123
# Enad Global 7            2.607784      5.211340  0.269918  1.224138
# Zinzino                  1.576389      1.968000  0.203803  0.881100
# Swedencare               1.723404      2.440860  0.210287  1.012446
# Cantargia                2.038902      2.531915  0.059011  0.889880
# Biovica                  1.354545      3.371308  0.254784  0.791684
# Sinch                    0.682152      3.640809  0.326546  0.804129
# BHG Group                1.074830      2.075630  0.227858  0.717737
# Boozt                    0.926316      2.439850  0.148949  0.716891
# Volati                   1.500000      1.506024  0.228704  0.797877
# Ascelia Pharma           1.225743      1.401709  0.270774  0.865220
# Sdiptech                 0.948718      2.064516  0.176896  0.614685
# OrganoClick              0.978799      1.093458  0.371070  0.782191
# Eolus Vind               0.933333      1.430476  0.408155  0.776707
# Intervacc                1.089669      1.748718  0.163649  0.602983
# Kambi                    0.910058      1.954376  0.191022  0.709764
# G5 Entertainment         1.085378      3.158513  0.061470  0.526672
# VNV Global               0.704871      0.882911  0.334530  0.646330
# Cellink                  0.898496      1.885714  0.285930  0.604295
# Mips                     0.653226      1.727738  0.221973  0.529475
# GARO                     0.771588      1.015848  0.109560  0.495529
# Invisio                  0.623377      1.115059  0.277283  0.597434
# Sivers Semiconductors    2.290766      3.240506  0.212143  0.731978
#
# Bolagsnamn            Momentum rank                       Antal aktier
#                             Rank 3m Rank 6m Rank 1 år Tot
# Azelio                            1       1         4   1           88
# Bayn Group                        2       4         2   2          349
# Bambuser                          4       6         1   3          299
# Enad Global 7                     8       2         3   4           43
# Zinzino                           3       8        14   5           70
# Swedencare                        9       7        10   6           16
# Cantargia                        20       5         9   7           78
# Biovica                          19      10         6   8          100
# Sinch                             6      26         5   9            4
# BHG Group                        15      14        12  10           28
# Boozt                            14      18        11  11           28
# Volati                           12       9        22  12           50
# Ascelia Pharma                   10      11        24  13           93
# Sdiptech                         16      16        13  14           23
# OrganoClick                       5      15        28  15          464
# Eolus Vind                       11      17        23  16           20
# Intervacc                        23      12        18  17           97
# Kambi                            21      19        15  18           13
# G5 Entertainment                 48      13         8  19           12
# VNV Global                        7      25        37  20           44
# Cellink                          35      20        16  21           21
# Mips                             22      32        19  22           10
# GARO                             24      21        29  23            8
# Invisio                          13      35        27  24           21
# Sivers Semiconductors            66       3         7  25          155

# %%
# Display number of companies from First North

nfn = sum(df_filt.head(NO_COMPS_TO_BUY)['Info']['Lista'] == 'First North')
print('Companies on First North:', nfn)
# Out:
# Companies on First North: 12
